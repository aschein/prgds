# %%
import numpy as np
import numpy.random as rn
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as st

import sys
from path import Path
sys.path.append('..')
from apf.models.bpmf import BPMF

# %%
seed = 222
rn.seed(seed)

n_samps = 100
n_feats = 200
n_comps = 10

eps = 0.1
b = 10

b = rn.gamma(eps, 1./eps)
Theta_IK = rn.gamma(eps, 1./(eps * b), size=(n_samps, n_comps))
Phi_KJ = rn.dirichlet(np.ones(n_feats), size=n_comps)
Lambda_K = rn.gamma(eps, 1./eps, size=n_comps)
Mu_IJ = Theta_IK.dot(Phi_KJ)

Y_IJ = rn.poisson(Mu_IJ)                        # count data
B_IJ = (Y_IJ > 0).astype(int)                   # binarized data
mask_IJ = rn.binomial(1, 0.1, size=Y_IJ.shape)  # randomly make 10% missing

count_data = np.ma.MaskedArray(Y_IJ, mask_IJ.astype(bool))  # create masked count data
binary_data = np.ma.MaskedArray(B_IJ, mask_IJ.astype(bool)) # create masked binary data

# %%
K = 15
model = BPMF(n_samps=count_data.shape[0],
             n_feats=count_data.shape[1],
             n_comps=K,
             binary=False,
             n_threads=3)

burnin = 1000  # 1000 iterations of burnin
model.fit(count_data, 
          n_itns=burnin, 
          initialize=True,
          verbose=250)

n_epochs = 100  # number of Gibbs sampling epochs
n_itns = 50     # number of Gibbs iterations per epoch

prob_IJ = np.zeros(count_data.shape)
for epoch in range(n_epochs):
    model.fit(count_data, 
              n_itns=n_itns, 
              initialize=False,
              verbose=50)
    
    pred_IJ = model.reconstruct()
    prob_IJ += st.poisson.pmf(count_data.data, pred_IJ)
prob_IJ /= float(n_epochs)

mask = count_data.mask
test_data = count_data.data[mask]
train_data = count_data.data[~mask]

test_ppd = np.exp(np.mean(np.log(prob_IJ[mask])))
train_ppd = np.exp(np.mean(np.log(prob_IJ[~mask])))

print(f'Pointwise predictive density on training data: {train_ppd}')
print(f'Pointwise predictive density on test data: {test_ppd}')
# Out:
# INITIALIZING...
#
#
# STARTING INFERENCE...
#
# 0.0360ms: sampling b
# 1.4708ms: sampling Lambda_K
# 0.9370ms: sampling Theta_IK
# 0.3889ms: sampling Phi_KJ
# 7.6892ms: sampling Y_PK
# ITERATION 250
#
# 0.0219ms: sampling b
# 1.2150ms: sampling Lambda_K
# 0.7570ms: sampling Theta_IK
# 0.3231ms: sampling Phi_KJ
# 7.5612ms: sampling Y_PK
# ITERATION 500
#
# 0.0210ms: sampling b
# 1.2081ms: sampling Lambda_K
# 1.3211ms: sampling Theta_IK
# 0.7460ms: sampling Phi_KJ
# 7.9103ms: sampling Y_PK
# ITERATION 750
#
# 0.0331ms: sampling b
# 1.1110ms: sampling Lambda_K
# 1.0180ms: sampling Theta_IK
# 0.3541ms: sampling Phi_KJ
# 7.7429ms: sampling Y_PK
# ITERATION 1000
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1382ms: sampling Lambda_K
# 0.9570ms: sampling Theta_IK
# 0.3531ms: sampling Phi_KJ
# 7.6058ms: sampling Y_PK
# ITERATION 1050
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.3189ms: sampling Lambda_K
# 0.9809ms: sampling Theta_IK
# 0.3459ms: sampling Phi_KJ
# 7.7100ms: sampling Y_PK
# ITERATION 1100
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.1051ms: sampling Lambda_K
# 1.1091ms: sampling Theta_IK
# 0.3049ms: sampling Phi_KJ
# 7.6921ms: sampling Y_PK
# ITERATION 1150
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.2660ms: sampling Lambda_K
# 1.1363ms: sampling Theta_IK
# 0.5271ms: sampling Phi_KJ
# 7.9460ms: sampling Y_PK
# ITERATION 1200
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1921ms: sampling Lambda_K
# 1.0087ms: sampling Theta_IK
# 0.3841ms: sampling Phi_KJ
# 7.8208ms: sampling Y_PK
# ITERATION 1250
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.1752ms: sampling Lambda_K
# 0.9608ms: sampling Theta_IK
# 0.3021ms: sampling Phi_KJ
# 7.5412ms: sampling Y_PK
# ITERATION 1300
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.2057ms: sampling Lambda_K
# 1.1101ms: sampling Theta_IK
# 0.3510ms: sampling Phi_KJ
# 7.7341ms: sampling Y_PK
# ITERATION 1350
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0400ms: sampling Lambda_K
# 0.9570ms: sampling Theta_IK
# 0.3648ms: sampling Phi_KJ
# 7.6480ms: sampling Y_PK
# ITERATION 1400
#
#
# STARTING INFERENCE...
#
# 0.0267ms: sampling b
# 1.4129ms: sampling Lambda_K
# 1.0049ms: sampling Theta_IK
# 0.4170ms: sampling Phi_KJ
# 7.9200ms: sampling Y_PK
# ITERATION 1450
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.3030ms: sampling Lambda_K
# 1.3721ms: sampling Theta_IK
# 0.4802ms: sampling Phi_KJ
# 7.7507ms: sampling Y_PK
# ITERATION 1500
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0579ms: sampling Lambda_K
# 0.8659ms: sampling Theta_IK
# 0.3529ms: sampling Phi_KJ
# 7.7419ms: sampling Y_PK
# ITERATION 1550
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1342ms: sampling Lambda_K
# 1.0953ms: sampling Theta_IK
# 0.5081ms: sampling Phi_KJ
# 7.8948ms: sampling Y_PK
# ITERATION 1600
#
#
# STARTING INFERENCE...
#
# 0.0348ms: sampling b
# 0.9971ms: sampling Lambda_K
# 0.9360ms: sampling Theta_IK
# 0.3631ms: sampling Phi_KJ
# 7.6129ms: sampling Y_PK
# ITERATION 1650
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1129ms: sampling Lambda_K
# 0.9339ms: sampling Theta_IK
# 0.3462ms: sampling Phi_KJ
# 7.5619ms: sampling Y_PK
# ITERATION 1700
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.0400ms: sampling Lambda_K
# 0.9508ms: sampling Theta_IK
# 0.3421ms: sampling Phi_KJ
# 7.7128ms: sampling Y_PK
# ITERATION 1750
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.2670ms: sampling Lambda_K
# 1.0550ms: sampling Theta_IK
# 0.3362ms: sampling Phi_KJ
# 7.7271ms: sampling Y_PK
# ITERATION 1800
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0681ms: sampling Lambda_K
# 0.9301ms: sampling Theta_IK
# 0.3309ms: sampling Phi_KJ
# 7.6077ms: sampling Y_PK
# ITERATION 1850
#
#
# STARTING INFERENCE...
#
# 0.0520ms: sampling b
# 1.0929ms: sampling Lambda_K
# 1.0850ms: sampling Theta_IK
# 0.4148ms: sampling Phi_KJ
# 7.6900ms: sampling Y_PK
# ITERATION 1900
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.0259ms: sampling Lambda_K
# 0.9980ms: sampling Theta_IK
# 0.3781ms: sampling Phi_KJ
# 7.5870ms: sampling Y_PK
# ITERATION 1950
#
#
# STARTING INFERENCE...
#
# 0.0319ms: sampling b
# 1.0679ms: sampling Lambda_K
# 0.8881ms: sampling Theta_IK
# 0.3059ms: sampling Phi_KJ
# 7.6940ms: sampling Y_PK
# ITERATION 2000
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0707ms: sampling Lambda_K
# 0.8841ms: sampling Theta_IK
# 0.3610ms: sampling Phi_KJ
# 7.6141ms: sampling Y_PK
# ITERATION 2050
#
#
# STARTING INFERENCE...
#
# 0.0341ms: sampling b
# 1.1530ms: sampling Lambda_K
# 1.0231ms: sampling Theta_IK
# 0.3483ms: sampling Phi_KJ
# 7.5891ms: sampling Y_PK
# ITERATION 2100
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0240ms: sampling Lambda_K
# 0.9580ms: sampling Theta_IK
# 0.5169ms: sampling Phi_KJ
# 7.5243ms: sampling Y_PK
# ITERATION 2150
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0958ms: sampling Lambda_K
# 0.9339ms: sampling Theta_IK
# 0.3259ms: sampling Phi_KJ
# 7.6220ms: sampling Y_PK
# ITERATION 2200
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.0920ms: sampling Lambda_K
# 0.8819ms: sampling Theta_IK
# 0.3252ms: sampling Phi_KJ
# 7.6840ms: sampling Y_PK
# ITERATION 2250
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0419ms: sampling Lambda_K
# 0.9911ms: sampling Theta_IK
# 0.3362ms: sampling Phi_KJ
# 7.5660ms: sampling Y_PK
# ITERATION 2300
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.1892ms: sampling Lambda_K
# 0.9701ms: sampling Theta_IK
# 0.5028ms: sampling Phi_KJ
# 7.6690ms: sampling Y_PK
# ITERATION 2350
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 0.9789ms: sampling Lambda_K
# 0.8888ms: sampling Theta_IK
# 0.3448ms: sampling Phi_KJ
# 7.6783ms: sampling Y_PK
# ITERATION 2400
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1780ms: sampling Lambda_K
# 0.9313ms: sampling Theta_IK
# 0.3541ms: sampling Phi_KJ
# 7.6411ms: sampling Y_PK
# ITERATION 2450
#
#
# STARTING INFERENCE...
#
# 0.0200ms: sampling b
# 1.4391ms: sampling Lambda_K
# 1.2228ms: sampling Theta_IK
# 0.6180ms: sampling Phi_KJ
# 7.8464ms: sampling Y_PK
# ITERATION 2500
#
#
# STARTING INFERENCE...
#
# 0.0200ms: sampling b
# 1.0929ms: sampling Lambda_K
# 1.0409ms: sampling Theta_IK
# 0.4838ms: sampling Phi_KJ
# 7.7620ms: sampling Y_PK
# ITERATION 2550
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0080ms: sampling Lambda_K
# 0.9179ms: sampling Theta_IK
# 0.4909ms: sampling Phi_KJ
# 7.8080ms: sampling Y_PK
# ITERATION 2600
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1342ms: sampling Lambda_K
# 0.7889ms: sampling Theta_IK
# 0.3181ms: sampling Phi_KJ
# 7.5762ms: sampling Y_PK
# ITERATION 2650
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1861ms: sampling Lambda_K
# 0.8829ms: sampling Theta_IK
# 0.3300ms: sampling Phi_KJ
# 7.6389ms: sampling Y_PK
# ITERATION 2700
#
#
# STARTING INFERENCE...
#
# 0.0360ms: sampling b
# 1.0571ms: sampling Lambda_K
# 0.9520ms: sampling Theta_IK
# 0.5252ms: sampling Phi_KJ
# 7.8082ms: sampling Y_PK
# ITERATION 2750
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0803ms: sampling Lambda_K
# 0.9379ms: sampling Theta_IK
# 0.3400ms: sampling Phi_KJ
# 7.6771ms: sampling Y_PK
# ITERATION 2800
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0648ms: sampling Lambda_K
# 0.9131ms: sampling Theta_IK
# 0.3557ms: sampling Phi_KJ
# 7.7229ms: sampling Y_PK
# ITERATION 2850
#
#
# STARTING INFERENCE...
#
# 0.0200ms: sampling b
# 1.0781ms: sampling Lambda_K
# 0.9089ms: sampling Theta_IK
# 0.3479ms: sampling Phi_KJ
# 7.7381ms: sampling Y_PK
# ITERATION 2900
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1179ms: sampling Lambda_K
# 0.9048ms: sampling Theta_IK
# 0.5572ms: sampling Phi_KJ
# 7.7000ms: sampling Y_PK
# ITERATION 2950
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0099ms: sampling Lambda_K
# 1.0028ms: sampling Theta_IK
# 0.3459ms: sampling Phi_KJ
# 7.6048ms: sampling Y_PK
# ITERATION 3000
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1449ms: sampling Lambda_K
# 1.0262ms: sampling Theta_IK
# 0.3703ms: sampling Phi_KJ
# 7.6809ms: sampling Y_PK
# ITERATION 3050
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0831ms: sampling Lambda_K
# 1.0121ms: sampling Theta_IK
# 0.3531ms: sampling Phi_KJ
# 7.6530ms: sampling Y_PK
# ITERATION 3100
#
#
# STARTING INFERENCE...
#
# 0.0200ms: sampling b
# 0.9880ms: sampling Lambda_K
# 1.0772ms: sampling Theta_IK
# 0.3359ms: sampling Phi_KJ
# 7.7519ms: sampling Y_PK
# ITERATION 3150
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0059ms: sampling Lambda_K
# 0.9148ms: sampling Theta_IK
# 0.3610ms: sampling Phi_KJ
# 7.7491ms: sampling Y_PK
# ITERATION 3200
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.0481ms: sampling Lambda_K
# 1.0340ms: sampling Theta_IK
# 0.3822ms: sampling Phi_KJ
# 7.7472ms: sampling Y_PK
# ITERATION 3250
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0402ms: sampling Lambda_K
# 1.1919ms: sampling Theta_IK
# 0.3741ms: sampling Phi_KJ
# 7.6132ms: sampling Y_PK
# ITERATION 3300
#
#
# STARTING INFERENCE...
# 0.0219ms: sampling b
# 1.2000ms: sampling Lambda_K
# 0.7958ms: sampling Theta_IK
# 0.3443ms: sampling Phi_KJ
# 7.6020ms: sampling Y_PK
# ITERATION 3350
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0581ms: sampling Lambda_K
# 0.9310ms: sampling Theta_IK
# 0.4210ms: sampling Phi_KJ
# 7.6339ms: sampling Y_PK
# ITERATION 3400
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.1053ms: sampling Lambda_K
# 1.0638ms: sampling Theta_IK
# 0.4239ms: sampling Phi_KJ
# 7.6947ms: sampling Y_PK
# ITERATION 3450
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.0002ms: sampling Lambda_K
# 1.0688ms: sampling Theta_IK
# 0.4029ms: sampling Phi_KJ
# 7.6041ms: sampling Y_PK
# ITERATION 3500
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0760ms: sampling Lambda_K
# 0.8910ms: sampling Theta_IK
# 0.4542ms: sampling Phi_KJ
# 7.6501ms: sampling Y_PK
# ITERATION 3550
#
#
# STARTING INFERENCE...
#
# 0.0241ms: sampling b
# 1.0340ms: sampling Lambda_K
# 0.9360ms: sampling Theta_IK
# 0.3562ms: sampling Phi_KJ
# 7.7150ms: sampling Y_PK
# ITERATION 3600
#
#
# STARTING INFERENCE...
#
# 0.0319ms: sampling b
# 1.0970ms: sampling Lambda_K
# 0.9701ms: sampling Theta_IK
# 0.3262ms: sampling Phi_KJ
# 7.6561ms: sampling Y_PK
# ITERATION 3650
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.2531ms: sampling Lambda_K
# 1.0071ms: sampling Theta_IK
# 0.3569ms: sampling Phi_KJ
# 7.5960ms: sampling Y_PK
# ITERATION 3700
#
#
# STARTING INFERENCE...
#
# 0.0217ms: sampling b
# 1.0970ms: sampling Lambda_K
# 0.8812ms: sampling Theta_IK
# 0.3493ms: sampling Phi_KJ
# 7.6606ms: sampling Y_PK
# ITERATION 3750
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0660ms: sampling Lambda_K
# 0.9811ms: sampling Theta_IK
# 0.3371ms: sampling Phi_KJ
# 7.6330ms: sampling Y_PK
# ITERATION 3800
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0178ms: sampling Lambda_K
# 1.0660ms: sampling Theta_IK
# 0.4702ms: sampling Phi_KJ
# 8.1742ms: sampling Y_PK
# ITERATION 3850
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0750ms: sampling Lambda_K
# 0.9551ms: sampling Theta_IK
# 0.3531ms: sampling Phi_KJ
# 7.6208ms: sampling Y_PK
# ITERATION 3900
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.2403ms: sampling Lambda_K
# 0.9220ms: sampling Theta_IK
# 0.3290ms: sampling Phi_KJ
# 7.6830ms: sampling Y_PK
# ITERATION 3950
#
#
# STARTING INFERENCE...
#
# 0.0200ms: sampling b
# 1.2600ms: sampling Lambda_K
# 1.0014ms: sampling Theta_IK
# 0.3290ms: sampling Phi_KJ
# 7.6430ms: sampling Y_PK
# ITERATION 4000
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0481ms: sampling Lambda_K
# 1.0409ms: sampling Theta_IK
# 0.3369ms: sampling Phi_KJ
# 7.5519ms: sampling Y_PK
# ITERATION 4050
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.7757ms: sampling Lambda_K
# 1.1671ms: sampling Theta_IK
# 0.4590ms: sampling Phi_KJ
# 8.0032ms: sampling Y_PK
# ITERATION 4100
#
#
# STARTING INFERENCE...
#
# 0.0203ms: sampling b
# 1.3399ms: sampling Lambda_K
# 1.1280ms: sampling Theta_IK
# 0.3421ms: sampling Phi_KJ
# 7.7660ms: sampling Y_PK
# ITERATION 4150
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0540ms: sampling Lambda_K
# 0.9291ms: sampling Theta_IK
# 0.5069ms: sampling Phi_KJ
# 7.7336ms: sampling Y_PK
# ITERATION 4200
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.2610ms: sampling Lambda_K
# 0.8719ms: sampling Theta_IK
# 0.3238ms: sampling Phi_KJ
# 7.5638ms: sampling Y_PK
# ITERATION 4250
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1489ms: sampling Lambda_K
# 0.8907ms: sampling Theta_IK
# 0.3331ms: sampling Phi_KJ
# 7.6258ms: sampling Y_PK
# ITERATION 4300
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.0719ms: sampling Lambda_K
# 0.9131ms: sampling Theta_IK
# 0.3881ms: sampling Phi_KJ
# 7.7009ms: sampling Y_PK
# ITERATION 4350
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0679ms: sampling Lambda_K
# 1.0149ms: sampling Theta_IK
# 0.3469ms: sampling Phi_KJ
# 7.7450ms: sampling Y_PK
# ITERATION 4400
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1570ms: sampling Lambda_K
# 0.9661ms: sampling Theta_IK
# 0.3412ms: sampling Phi_KJ
# 7.6849ms: sampling Y_PK
# ITERATION 4450
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.0812ms: sampling Lambda_K
# 0.9863ms: sampling Theta_IK
# 0.3510ms: sampling Phi_KJ
# 7.6652ms: sampling Y_PK
# ITERATION 4500
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.5237ms: sampling Lambda_K
# 1.1911ms: sampling Theta_IK
# 0.2728ms: sampling Phi_KJ
# 7.5300ms: sampling Y_PK
# ITERATION 4550
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.2999ms: sampling Lambda_K
# 1.1690ms: sampling Theta_IK
# 0.4401ms: sampling Phi_KJ
# 7.6811ms: sampling Y_PK
# ITERATION 4600
#
#
# STARTING INFERENCE...
#
# 0.0482ms: sampling b
# 1.1511ms: sampling Lambda_K
# 1.0571ms: sampling Theta_IK
# 0.3059ms: sampling Phi_KJ
# 7.6489ms: sampling Y_PK
# ITERATION 4650
#
#
# STARTING INFERENCE...
#
# 0.0226ms: sampling b
# 1.0960ms: sampling Lambda_K
# 0.9570ms: sampling Theta_IK
# 0.3889ms: sampling Phi_KJ
# 7.8740ms: sampling Y_PK
# ITERATION 4700
#
#
# STARTING INFERENCE...
#
# 0.0200ms: sampling b
# 1.0717ms: sampling Lambda_K
# 0.9212ms: sampling Theta_IK
# 0.3822ms: sampling Phi_KJ
# 7.7393ms: sampling Y_PK
# ITERATION 4750
#
#
# STARTING INFERENCE...
#
# 0.0241ms: sampling b
# 1.0800ms: sampling Lambda_K
# 0.8721ms: sampling Theta_IK
# 0.3469ms: sampling Phi_KJ
# 7.6420ms: sampling Y_PK
# ITERATION 4800
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0450ms: sampling Lambda_K
# 0.9398ms: sampling Theta_IK
# 0.3288ms: sampling Phi_KJ
# 7.8049ms: sampling Y_PK
# ITERATION 4850
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.0140ms: sampling Lambda_K
# 0.8991ms: sampling Theta_IK
# 0.3440ms: sampling Phi_KJ
# 7.6082ms: sampling Y_PK
# ITERATION 4900
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1218ms: sampling Lambda_K
# 0.9677ms: sampling Theta_IK
# 0.3369ms: sampling Phi_KJ
# 7.6048ms: sampling Y_PK
# ITERATION 4950
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1659ms: sampling Lambda_K
# 0.7749ms: sampling Theta_IK
# 0.3588ms: sampling Phi_KJ
# 7.6399ms: sampling Y_PK
# ITERATION 5000
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.0600ms: sampling Lambda_K
# 0.9651ms: sampling Theta_IK
# 0.4051ms: sampling Phi_KJ
# 8.9748ms: sampling Y_PK
# ITERATION 5050
#
#
# STARTING INFERENCE...
#
# 0.0651ms: sampling b
# 1.1160ms: sampling Lambda_K
# 0.9930ms: sampling Theta_IK
# 0.3300ms: sampling Phi_KJ
# 7.5312ms: sampling Y_PK
# ITERATION 5100
#
#
# STARTING INFERENCE...
#
# 0.0191ms: sampling b
# 1.0440ms: sampling Lambda_K
# 1.1053ms: sampling Theta_IK
# 0.4401ms: sampling Phi_KJ
# 7.8840ms: sampling Y_PK
# ITERATION 5150
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0390ms: sampling Lambda_K
# 1.1067ms: sampling Theta_IK
# 0.3469ms: sampling Phi_KJ
# 7.5998ms: sampling Y_PK
# ITERATION 5200
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1063ms: sampling Lambda_K
# 1.0459ms: sampling Theta_IK
# 0.3099ms: sampling Phi_KJ
# 7.6139ms: sampling Y_PK
# ITERATION 5250
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0538ms: sampling Lambda_K
# 1.0500ms: sampling Theta_IK
# 0.3378ms: sampling Phi_KJ
# 7.8170ms: sampling Y_PK
# ITERATION 5300
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.2000ms: sampling Lambda_K
# 1.0071ms: sampling Theta_IK
# 0.4621ms: sampling Phi_KJ
# 7.9241ms: sampling Y_PK
# ITERATION 5350
#
#
# STARTING INFERENCE...
#
# 0.0200ms: sampling b
# 1.1482ms: sampling Lambda_K
# 0.9460ms: sampling Theta_IK
# 0.3459ms: sampling Phi_KJ
# 7.5934ms: sampling Y_PK
# ITERATION 5400
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0009ms: sampling Lambda_K
# 1.0719ms: sampling Theta_IK
# 0.3431ms: sampling Phi_KJ
# 7.7171ms: sampling Y_PK
# ITERATION 5450
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0769ms: sampling Lambda_K
# 1.0209ms: sampling Theta_IK
# 0.4711ms: sampling Phi_KJ
# 7.6592ms: sampling Y_PK
# ITERATION 5500
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.1089ms: sampling Lambda_K
# 0.9122ms: sampling Theta_IK
# 0.3700ms: sampling Phi_KJ
# 7.7407ms: sampling Y_PK
# ITERATION 5550
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.4310ms: sampling Lambda_K
# 0.9830ms: sampling Theta_IK
# 0.2990ms: sampling Phi_KJ
# 7.6022ms: sampling Y_PK
# ITERATION 5600
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0960ms: sampling Lambda_K
# 0.7582ms: sampling Theta_IK
# 0.3970ms: sampling Phi_KJ
# 7.6480ms: sampling Y_PK
# ITERATION 5650
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1311ms: sampling Lambda_K
# 1.1730ms: sampling Theta_IK
# 0.5770ms: sampling Phi_KJ
# 8.1801ms: sampling Y_PK
# ITERATION 5700
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1201ms: sampling Lambda_K
# 0.9959ms: sampling Theta_IK
# 0.3672ms: sampling Phi_KJ
# 7.6759ms: sampling Y_PK
# ITERATION 5750
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1780ms: sampling Lambda_K
# 0.7920ms: sampling Theta_IK
# 0.3529ms: sampling Phi_KJ
# 7.6170ms: sampling Y_PK
# ITERATION 5800
#
#
# STARTING INFERENCE...
# 0.0231ms: sampling b
# 0.9880ms: sampling Lambda_K
# 0.9429ms: sampling Theta_IK
# 0.3371ms: sampling Phi_KJ
# 7.7252ms: sampling Y_PK
# ITERATION 5850
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1010ms: sampling Lambda_K
# 0.8769ms: sampling Theta_IK
# 0.3340ms: sampling Phi_KJ
# 7.5929ms: sampling Y_PK
# ITERATION 5900
#
#
# STARTING INFERENCE...
#
# 0.0200ms: sampling b
# 1.3130ms: sampling Lambda_K
# 0.9258ms: sampling Theta_IK
# 0.3738ms: sampling Phi_KJ
# 7.5891ms: sampling Y_PK
# ITERATION 5950
#
#
# STARTING INFERENCE...
#
# 0.0250ms: sampling b
# 1.0791ms: sampling Lambda_K
# 0.9928ms: sampling Theta_IK
# 0.3538ms: sampling Phi_KJ
# 7.5567ms: sampling Y_PK
# ITERATION 6000
#
# Pointwise predictive density on training data: 0.27395914321085585
# Pointwise predictive density on test data: 0.22617194965412216

# %%
K = 15
model = BPMF(n_samps=binary_data.shape[0],
             n_feats=binary_data.shape[1],
             n_comps=K,
             binary=True,
             n_threads=3)

burnin = 1000  # 1000 iterations of burnin
model.fit(binary_data, 
          n_itns=burnin, 
          initialize=True,
          verbose=250)

n_epochs = 100  # number of Gibbs sampling epochs
n_itns = 50     # number of Gibbs iterations per epoch

prob_IJ = np.zeros(binary_data.shape)
for epoch in range(n_epochs):
    model.fit(binary_data, 
              n_itns=n_itns, 
              initialize=False,
              verbose=50)
    
    pred_IJ = -np.expm1(-model.reconstruct())
    prob_IJ += st.bernoulli.pmf(binary_data.data, pred_IJ)
prob_IJ /= float(n_epochs)

mask = binary_data.mask
test_data = binary_data.data[mask]
train_data = binary_data.data[~mask]

test_ppd = np.exp(np.mean(np.log(prob_IJ[mask])))
train_ppd = np.exp(np.mean(np.log(prob_IJ[~mask])))

print(f'Pointwise predictive density on training data: {train_ppd}')
print(f'Pointwise predictive density on test data: {test_ppd}')
# Out:
# INITIALIZING...
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1311ms: sampling Lambda_K
# 0.9921ms: sampling Theta_IK
# 0.3550ms: sampling Phi_KJ
# 7.9479ms: sampling Y_PK
# ITERATION 250
#
# 0.0219ms: sampling b
# 1.1320ms: sampling Lambda_K
# 0.8929ms: sampling Theta_IK
# 0.3181ms: sampling Phi_KJ
# 7.9591ms: sampling Y_PK
# ITERATION 500
#
# 0.0219ms: sampling b
# 1.0402ms: sampling Lambda_K
# 1.0989ms: sampling Theta_IK
# 0.3841ms: sampling Phi_KJ
# 8.1189ms: sampling Y_PK
# ITERATION 750
#
# 0.0200ms: sampling b
# 1.5218ms: sampling Lambda_K
# 1.0860ms: sampling Theta_IK
# 0.3860ms: sampling Phi_KJ
# 8.1708ms: sampling Y_PK
# ITERATION 1000
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.1261ms: sampling Lambda_K
# 0.9890ms: sampling Theta_IK
# 0.3459ms: sampling Phi_KJ
# 8.1389ms: sampling Y_PK
# ITERATION 1050
#
#
# STARTING INFERENCE...
#
# 0.0241ms: sampling b
# 1.0240ms: sampling Lambda_K
# 0.9868ms: sampling Theta_IK
# 0.3409ms: sampling Phi_KJ
# 8.2850ms: sampling Y_PK
# ITERATION 1100
#
#
# STARTING INFERENCE...
#
# 0.0203ms: sampling b
# 1.2560ms: sampling Lambda_K
# 1.0858ms: sampling Theta_IK
# 0.4060ms: sampling Phi_KJ
# 7.9739ms: sampling Y_PK
# ITERATION 1150
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1840ms: sampling Lambda_K
# 0.8049ms: sampling Theta_IK
# 0.3312ms: sampling Phi_KJ
# 8.2130ms: sampling Y_PK
# ITERATION 1200
#
#
# STARTING INFERENCE...
#
# 0.0360ms: sampling b
# 1.0331ms: sampling Lambda_K
# 0.8790ms: sampling Theta_IK
# 0.3350ms: sampling Phi_KJ
# 8.1038ms: sampling Y_PK
# ITERATION 1250
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0421ms: sampling Lambda_K
# 0.8838ms: sampling Theta_IK
# 0.3572ms: sampling Phi_KJ
# 8.1170ms: sampling Y_PK
# ITERATION 1300
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 0.9971ms: sampling Lambda_K
# 0.9091ms: sampling Theta_IK
# 0.3309ms: sampling Phi_KJ
# 8.0721ms: sampling Y_PK
# ITERATION 1350
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0579ms: sampling Lambda_K
# 0.9501ms: sampling Theta_IK
# 0.3309ms: sampling Phi_KJ
# 8.1081ms: sampling Y_PK
# ITERATION 1400
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.2610ms: sampling Lambda_K
# 1.8010ms: sampling Theta_IK
# 0.7761ms: sampling Phi_KJ
# 8.7888ms: sampling Y_PK
# ITERATION 1450
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0629ms: sampling Lambda_K
# 0.8869ms: sampling Theta_IK
# 0.3459ms: sampling Phi_KJ
# 8.1558ms: sampling Y_PK
# ITERATION 1500
#
#
# STARTING INFERENCE...
#
# 0.0241ms: sampling b
# 1.0481ms: sampling Lambda_K
# 0.9840ms: sampling Theta_IK
# 0.4408ms: sampling Phi_KJ
# 8.2769ms: sampling Y_PK
# ITERATION 1550
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1251ms: sampling Lambda_K
# 0.9241ms: sampling Theta_IK
# 0.3550ms: sampling Phi_KJ
# 7.9641ms: sampling Y_PK
# ITERATION 1600
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.4961ms: sampling Lambda_K
# 1.4362ms: sampling Theta_IK
# 0.3688ms: sampling Phi_KJ
# 8.0969ms: sampling Y_PK
# ITERATION 1650
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.2028ms: sampling Lambda_K
# 1.0455ms: sampling Theta_IK
# 0.6070ms: sampling Phi_KJ
# 8.1291ms: sampling Y_PK
# ITERATION 1700
#
#
# STARTING INFERENCE...
#
# 0.0241ms: sampling b
# 1.0362ms: sampling Lambda_K
# 1.0798ms: sampling Theta_IK
# 0.3462ms: sampling Phi_KJ
# 8.0569ms: sampling Y_PK
# ITERATION 1750
#
#
# STARTING INFERENCE...
#
# 0.0331ms: sampling b
# 1.1060ms: sampling Lambda_K
# 1.1251ms: sampling Theta_IK
# 0.3731ms: sampling Phi_KJ
# 8.1558ms: sampling Y_PK
# ITERATION 1800
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 0.8740ms: sampling Lambda_K
# 0.9592ms: sampling Theta_IK
# 0.3359ms: sampling Phi_KJ
# 8.1189ms: sampling Y_PK
# ITERATION 1850
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0078ms: sampling Lambda_K
# 0.8869ms: sampling Theta_IK
# 0.3169ms: sampling Phi_KJ
# 8.2433ms: sampling Y_PK
# ITERATION 1900
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.5869ms: sampling Lambda_K
# 0.9470ms: sampling Theta_IK
# 0.3221ms: sampling Phi_KJ
# 8.1248ms: sampling Y_PK
# ITERATION 1950
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0920ms: sampling Lambda_K
# 0.8688ms: sampling Theta_IK
# 0.3612ms: sampling Phi_KJ
# 8.1348ms: sampling Y_PK
# ITERATION 2000
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0030ms: sampling Lambda_K
# 0.9511ms: sampling Theta_IK
# 0.3281ms: sampling Phi_KJ
# 7.9970ms: sampling Y_PK
# ITERATION 2050
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0180ms: sampling Lambda_K
# 1.0369ms: sampling Theta_IK
# 0.3169ms: sampling Phi_KJ
# 8.2431ms: sampling Y_PK
# ITERATION 2100
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0738ms: sampling Lambda_K
# 0.9527ms: sampling Theta_IK
# 0.3991ms: sampling Phi_KJ
# 8.2181ms: sampling Y_PK
# ITERATION 2150
#
#
# STARTING INFERENCE...
#
# 0.0203ms: sampling b
# 1.2028ms: sampling Lambda_K
# 0.9091ms: sampling Theta_IK
# 0.3550ms: sampling Phi_KJ
# 8.0590ms: sampling Y_PK
# ITERATION 2200
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0719ms: sampling Lambda_K
# 1.1420ms: sampling Theta_IK
# 0.3860ms: sampling Phi_KJ
# 8.3289ms: sampling Y_PK
# ITERATION 2250
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0769ms: sampling Lambda_K
# 0.9441ms: sampling Theta_IK
# 0.5240ms: sampling Phi_KJ
# 8.1618ms: sampling Y_PK
# ITERATION 2300
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 0.9363ms: sampling Lambda_K
# 1.1210ms: sampling Theta_IK
# 0.3300ms: sampling Phi_KJ
# 8.1160ms: sampling Y_PK
# ITERATION 2350
#
#
# STARTING INFERENCE...
#
# 0.1311ms: sampling b
# 1.1871ms: sampling Lambda_K
# 0.8419ms: sampling Theta_IK
# 0.3200ms: sampling Phi_KJ
# 8.0462ms: sampling Y_PK
# ITERATION 2400
#
#
# STARTING INFERENCE...
#
# 0.0339ms: sampling b
# 1.0381ms: sampling Lambda_K
# 0.9139ms: sampling Theta_IK
# 0.3600ms: sampling Phi_KJ
# 8.2088ms: sampling Y_PK
# ITERATION 2450
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.2200ms: sampling Lambda_K
# 0.9441ms: sampling Theta_IK
# 0.3231ms: sampling Phi_KJ
# 8.1990ms: sampling Y_PK
# ITERATION 2500
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.0753ms: sampling Lambda_K
# 0.8788ms: sampling Theta_IK
# 0.3419ms: sampling Phi_KJ
# 8.1308ms: sampling Y_PK
# ITERATION 2550
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0650ms: sampling Lambda_K
# 1.1420ms: sampling Theta_IK
# 0.3550ms: sampling Phi_KJ
# 8.2293ms: sampling Y_PK
# ITERATION 2600
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.2093ms: sampling Lambda_K
# 0.7842ms: sampling Theta_IK
# 0.3529ms: sampling Phi_KJ
# 8.2550ms: sampling Y_PK
# ITERATION 2650
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1559ms: sampling Lambda_K
# 0.8430ms: sampling Theta_IK
# 0.3431ms: sampling Phi_KJ
# 8.1270ms: sampling Y_PK
# ITERATION 2700
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.4663ms: sampling Lambda_K
# 1.2372ms: sampling Theta_IK
# 0.4852ms: sampling Phi_KJ
# 8.0342ms: sampling Y_PK
# ITERATION 2750
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0819ms: sampling Lambda_K
# 1.1499ms: sampling Theta_IK
# 0.5498ms: sampling Phi_KJ
# 8.2030ms: sampling Y_PK
# ITERATION 2800
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1690ms: sampling Lambda_K
# 0.9012ms: sampling Theta_IK
# 0.4220ms: sampling Phi_KJ
# 8.2529ms: sampling Y_PK
# ITERATION 2850
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0540ms: sampling Lambda_K
# 0.8359ms: sampling Theta_IK
# 0.3371ms: sampling Phi_KJ
# 8.1110ms: sampling Y_PK
# ITERATION 2900
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1930ms: sampling Lambda_K
# 0.9360ms: sampling Theta_IK
# 0.3610ms: sampling Phi_KJ
# 8.1389ms: sampling Y_PK
# ITERATION 2950
#
#
# STARTING INFERENCE...
#
# 0.0238ms: sampling b
# 1.0760ms: sampling Lambda_K
# 0.9139ms: sampling Theta_IK
# 0.3831ms: sampling Phi_KJ
# 8.2951ms: sampling Y_PK
# ITERATION 3000
#
#
# STARTING INFERENCE...
#
# 0.0212ms: sampling b
# 1.1542ms: sampling Lambda_K
# 0.9940ms: sampling Theta_IK
# 0.3471ms: sampling Phi_KJ
# 8.2190ms: sampling Y_PK
# ITERATION 3050
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 0.9880ms: sampling Lambda_K
# 0.9341ms: sampling Theta_IK
# 0.3319ms: sampling Phi_KJ
# 8.1372ms: sampling Y_PK
# ITERATION 3100
#
#
# STARTING INFERENCE...
#
# 0.0601ms: sampling b
# 1.2779ms: sampling Lambda_K
# 0.8137ms: sampling Theta_IK
# 0.3531ms: sampling Phi_KJ
# 8.0492ms: sampling Y_PK
# ITERATION 3150
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1468ms: sampling Lambda_K
# 1.0188ms: sampling Theta_IK
# 0.4277ms: sampling Phi_KJ
# 8.1811ms: sampling Y_PK
# ITERATION 3200
#
#
# STARTING INFERENCE...
#
# 0.0300ms: sampling b
# 1.1604ms: sampling Lambda_K
# 0.9069ms: sampling Theta_IK
# 0.3238ms: sampling Phi_KJ
# 8.0638ms: sampling Y_PK
# ITERATION 3250
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.0493ms: sampling Lambda_K
# 0.8419ms: sampling Theta_IK
# 0.3219ms: sampling Phi_KJ
# 8.2619ms: sampling Y_PK
# ITERATION 3300
#
#
# STARTING INFERENCE...
# 0.0231ms: sampling b
# 1.0290ms: sampling Lambda_K
# 0.9890ms: sampling Theta_IK
# 0.3459ms: sampling Phi_KJ
# 8.1041ms: sampling Y_PK
# ITERATION 3350
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 0.9930ms: sampling Lambda_K
# 1.0638ms: sampling Theta_IK
# 0.3221ms: sampling Phi_KJ
# 8.2021ms: sampling Y_PK
# ITERATION 3400
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.1480ms: sampling Lambda_K
# 0.9439ms: sampling Theta_IK
# 0.4771ms: sampling Phi_KJ
# 8.0833ms: sampling Y_PK
# ITERATION 3450
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.1053ms: sampling Lambda_K
# 0.8688ms: sampling Theta_IK
# 0.3338ms: sampling Phi_KJ
# 8.2009ms: sampling Y_PK
# ITERATION 3500
#
#
# STARTING INFERENCE...
#
# 0.0422ms: sampling b
# 1.0679ms: sampling Lambda_K
# 1.0421ms: sampling Theta_IK
# 0.3169ms: sampling Phi_KJ
# 8.0731ms: sampling Y_PK
# ITERATION 3550
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.1399ms: sampling Lambda_K
# 0.9718ms: sampling Theta_IK
# 0.3111ms: sampling Phi_KJ
# 8.0750ms: sampling Y_PK
# ITERATION 3600
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.0800ms: sampling Lambda_K
# 0.8929ms: sampling Theta_IK
# 0.3662ms: sampling Phi_KJ
# 8.3122ms: sampling Y_PK
# ITERATION 3650
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.1032ms: sampling Lambda_K
# 0.9189ms: sampling Theta_IK
# 0.3440ms: sampling Phi_KJ
# 8.1053ms: sampling Y_PK
# ITERATION 3700
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.0529ms: sampling Lambda_K
# 1.0641ms: sampling Theta_IK
# 0.3779ms: sampling Phi_KJ
# 8.4133ms: sampling Y_PK
# ITERATION 3750
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.2431ms: sampling Lambda_K
# 0.9770ms: sampling Theta_IK
# 0.5760ms: sampling Phi_KJ
# 8.3442ms: sampling Y_PK
# ITERATION 3800
#
#
# STARTING INFERENCE...
#
# 0.0241ms: sampling b
# 1.1590ms: sampling Lambda_K
# 0.9139ms: sampling Theta_IK
# 0.3440ms: sampling Phi_KJ
# 8.2610ms: sampling Y_PK
# ITERATION 3850
#
#
# STARTING INFERENCE...
#
# 0.0331ms: sampling b
# 1.1468ms: sampling Lambda_K
# 0.8838ms: sampling Theta_IK
# 0.3352ms: sampling Phi_KJ
# 8.1773ms: sampling Y_PK
# ITERATION 3900
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.3759ms: sampling Lambda_K
# 1.1489ms: sampling Theta_IK
# 0.4930ms: sampling Phi_KJ
# 8.2948ms: sampling Y_PK
# ITERATION 3950
#
#
# STARTING INFERENCE...
#
# 0.0217ms: sampling b
# 1.1830ms: sampling Lambda_K
# 0.8650ms: sampling Theta_IK
# 0.3262ms: sampling Phi_KJ
# 8.4729ms: sampling Y_PK
# ITERATION 4000
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1170ms: sampling Lambda_K
# 1.1830ms: sampling Theta_IK
# 0.5660ms: sampling Phi_KJ
# 8.5130ms: sampling Y_PK
# ITERATION 4050
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1289ms: sampling Lambda_K
# 0.9940ms: sampling Theta_IK
# 0.4721ms: sampling Phi_KJ
# 8.2560ms: sampling Y_PK
# ITERATION 4100
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1699ms: sampling Lambda_K
# 0.9060ms: sampling Theta_IK
# 0.3290ms: sampling Phi_KJ
# 8.2600ms: sampling Y_PK
# ITERATION 4150
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 0.9980ms: sampling Lambda_K
# 0.9489ms: sampling Theta_IK
# 0.3681ms: sampling Phi_KJ
# 8.1842ms: sampling Y_PK
# ITERATION 4200
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.0109ms: sampling Lambda_K
# 0.9408ms: sampling Theta_IK
# 0.3452ms: sampling Phi_KJ
# 8.5161ms: sampling Y_PK
# ITERATION 4250
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0800ms: sampling Lambda_K
# 1.0922ms: sampling Theta_IK
# 0.3660ms: sampling Phi_KJ
# 8.3520ms: sampling Y_PK
# ITERATION 4300
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1160ms: sampling Lambda_K
# 0.8950ms: sampling Theta_IK
# 0.3860ms: sampling Phi_KJ
# 8.1539ms: sampling Y_PK
# ITERATION 4350
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.3089ms: sampling Lambda_K
# 1.8990ms: sampling Theta_IK
# 0.6793ms: sampling Phi_KJ
# 8.1668ms: sampling Y_PK
# ITERATION 4400
#
#
# STARTING INFERENCE...
#
# 0.0250ms: sampling b
# 1.4181ms: sampling Lambda_K
# 1.1170ms: sampling Theta_IK
# 0.3481ms: sampling Phi_KJ
# 9.4023ms: sampling Y_PK
# ITERATION 4450
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0178ms: sampling Lambda_K
# 0.9711ms: sampling Theta_IK
# 0.3901ms: sampling Phi_KJ
# 8.1651ms: sampling Y_PK
# ITERATION 4500
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0870ms: sampling Lambda_K
# 0.9959ms: sampling Theta_IK
# 0.3710ms: sampling Phi_KJ
# 8.2140ms: sampling Y_PK
# ITERATION 4550
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.4219ms: sampling Lambda_K
# 1.1430ms: sampling Theta_IK
# 0.3788ms: sampling Phi_KJ
# 8.4188ms: sampling Y_PK
# ITERATION 4600
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.2560ms: sampling Lambda_K
# 1.0202ms: sampling Theta_IK
# 0.3960ms: sampling Phi_KJ
# 8.4112ms: sampling Y_PK
# ITERATION 4650
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0839ms: sampling Lambda_K
# 0.8950ms: sampling Theta_IK
# 0.3729ms: sampling Phi_KJ
# 8.3218ms: sampling Y_PK
# ITERATION 4700
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0359ms: sampling Lambda_K
# 0.8729ms: sampling Theta_IK
# 0.3603ms: sampling Phi_KJ
# 8.1971ms: sampling Y_PK
# ITERATION 4750
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.1330ms: sampling Lambda_K
# 1.1101ms: sampling Theta_IK
# 0.3829ms: sampling Phi_KJ
# 8.1391ms: sampling Y_PK
# ITERATION 4800
#
#
# STARTING INFERENCE...
#
# 0.0241ms: sampling b
# 1.4086ms: sampling Lambda_K
# 1.0090ms: sampling Theta_IK
# 0.3140ms: sampling Phi_KJ
# 8.1530ms: sampling Y_PK
# ITERATION 4850
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.2760ms: sampling Lambda_K
# 1.0717ms: sampling Theta_IK
# 0.3421ms: sampling Phi_KJ
# 8.2211ms: sampling Y_PK
# ITERATION 4900
#
#
# STARTING INFERENCE...
#
# 0.0410ms: sampling b
# 1.7080ms: sampling Lambda_K
# 1.2910ms: sampling Theta_IK
# 0.3929ms: sampling Phi_KJ
# 8.4610ms: sampling Y_PK
# ITERATION 4950
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1311ms: sampling Lambda_K
# 0.9499ms: sampling Theta_IK
# 0.5419ms: sampling Phi_KJ
# 8.6350ms: sampling Y_PK
# ITERATION 5000
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0068ms: sampling Lambda_K
# 0.9310ms: sampling Theta_IK
# 0.3650ms: sampling Phi_KJ
# 8.8379ms: sampling Y_PK
# ITERATION 5050
#
#
# STARTING INFERENCE...
#
# 0.0491ms: sampling b
# 1.9341ms: sampling Lambda_K
# 1.0493ms: sampling Theta_IK
# 0.3819ms: sampling Phi_KJ
# 8.1241ms: sampling Y_PK
# ITERATION 5100
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.0140ms: sampling Lambda_K
# 1.1771ms: sampling Theta_IK
# 0.3719ms: sampling Phi_KJ
# 8.1830ms: sampling Y_PK
# ITERATION 5150
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0507ms: sampling Lambda_K
# 0.9770ms: sampling Theta_IK
# 0.3591ms: sampling Phi_KJ
# 8.1122ms: sampling Y_PK
# ITERATION 5200
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.1899ms: sampling Lambda_K
# 0.9561ms: sampling Theta_IK
# 0.3502ms: sampling Phi_KJ
# 8.1809ms: sampling Y_PK
# ITERATION 5250
#
#
# STARTING INFERENCE...
#
# 0.0293ms: sampling b
# 1.0850ms: sampling Lambda_K
# 0.9589ms: sampling Theta_IK
# 0.3452ms: sampling Phi_KJ
# 8.3158ms: sampling Y_PK
# ITERATION 5300
#
#
# STARTING INFERENCE...
#
# 0.0200ms: sampling b
# 1.0381ms: sampling Lambda_K
# 1.4300ms: sampling Theta_IK
# 0.5851ms: sampling Phi_KJ
# 8.2302ms: sampling Y_PK
# ITERATION 5350
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.0910ms: sampling Lambda_K
# 1.0111ms: sampling Theta_IK
# 0.3340ms: sampling Phi_KJ
# 8.1820ms: sampling Y_PK
# ITERATION 5400
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.0960ms: sampling Lambda_K
# 1.0009ms: sampling Theta_IK
# 0.4611ms: sampling Phi_KJ
# 8.4400ms: sampling Y_PK
# ITERATION 5450
#
#
# STARTING INFERENCE...
#
# 0.0231ms: sampling b
# 1.4069ms: sampling Lambda_K
# 1.2159ms: sampling Theta_IK
# 0.5620ms: sampling Phi_KJ
# 9.1679ms: sampling Y_PK
# ITERATION 5500
#
#
# STARTING INFERENCE...
#
# 0.0241ms: sampling b
# 1.1010ms: sampling Lambda_K
# 0.8128ms: sampling Theta_IK
# 0.3572ms: sampling Phi_KJ
# 8.7962ms: sampling Y_PK
# ITERATION 5550
#
#
# STARTING INFERENCE...
#
# 0.0229ms: sampling b
# 1.1730ms: sampling Lambda_K
# 0.8547ms: sampling Theta_IK
# 0.3610ms: sampling Phi_KJ
# 8.1339ms: sampling Y_PK
# ITERATION 5600
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0779ms: sampling Lambda_K
# 0.9937ms: sampling Theta_IK
# 0.5300ms: sampling Phi_KJ
# 8.2178ms: sampling Y_PK
# ITERATION 5650
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.0149ms: sampling Lambda_K
# 0.9992ms: sampling Theta_IK
# 0.3650ms: sampling Phi_KJ
# 8.2939ms: sampling Y_PK
# ITERATION 5700
#
#
# STARTING INFERENCE...
#
# 0.0222ms: sampling b
# 1.0788ms: sampling Lambda_K
# 0.9491ms: sampling Theta_IK
# 0.4232ms: sampling Phi_KJ
# 8.4088ms: sampling Y_PK
# ITERATION 5750
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.0669ms: sampling Lambda_K
# 1.0180ms: sampling Theta_IK
# 0.3259ms: sampling Phi_KJ
# 8.1720ms: sampling Y_PK
# ITERATION 5800
#
#
# STARTING INFERENCE...
# 0.0231ms: sampling b
# 1.0707ms: sampling Lambda_K
# 0.8550ms: sampling Theta_IK
# 0.4559ms: sampling Phi_KJ
# 8.4779ms: sampling Y_PK
# ITERATION 5850
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.1110ms: sampling Lambda_K
# 0.9611ms: sampling Theta_IK
# 0.4327ms: sampling Phi_KJ
# 8.3930ms: sampling Y_PK
# ITERATION 5900
#
#
# STARTING INFERENCE...
#
# 0.0219ms: sampling b
# 1.2038ms: sampling Lambda_K
# 1.0052ms: sampling Theta_IK
# 0.2983ms: sampling Phi_KJ
# 8.2021ms: sampling Y_PK
# ITERATION 5950
#
#
# STARTING INFERENCE...
#
# 0.0210ms: sampling b
# 1.2729ms: sampling Lambda_K
# 0.9310ms: sampling Theta_IK
# 0.3181ms: sampling Phi_KJ
# 8.1711ms: sampling Y_PK
# ITERATION 6000
#
# Pointwise predictive density on training data: 0.7724739613414147
# Pointwise predictive density on test data: 0.6240841245979063
